# %% [markdown]
# # Twitter Credentials

# %%
from dotenv import dotenv_values

config = dotenv_values(".env")
CONSUMER_KEY = config['CONSUMER_KEY']
CONSUMER_SECRET = config['CONSUMER_SECRET']
BEARER_TOKEN = config['BEARER_TOKEN']

# %%
import requests
import os
import json

search_url = "https://api.twitter.com/2/tweets/search/recent"

# Optional params: start_time,end_time,since_id,until_id,max_results,next_token,
# expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields
query_params = {'query': '(from:twitterdev -is:retweet) OR #twitterdev','tweet.fields': 'author_id'}


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {BEARER_TOKEN}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


def main():
    json_response = connect_to_endpoint(search_url, query_params)
    print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
main()
# Out:
# {
#     "data": [
#         {
#             "author_id": "2244994945",
#             "edit_history_tweet_ids": [
#                 "1578414851688480769"
#             ],
#             "id": "1578414851688480769",
#             "text": "honesty hour: what is the hardest part about being a developer? \ud83d\uddef"
#         },
#         {
#             "author_id": "1360788857797550084",
#             "edit_history_tweet_ids": [
#                 "1578183052886704128"
#             ],
#             "id": "1578183052886704128",
#             "text": "what does this even mean #twitterdev \nisn't a stream a constant connection https://t.co/fs4KICLUCp"
#         },
#         {
#             "author_id": "2244994945",
#             "edit_history_tweet_ids": [
#                 "1578067569835229213"
#             ],
#             "id": "1578067569835229213",
#             "text": "\ud83d\udc49Using a solution like Audiense Connect in combination with Twitter API can help you engage the right target with your content. \ud83e\udd1d\n\nSee how @BancoPichincha developed El Diez de la Trivia and Trivia de Oro to enhance sponsorships with football teams \u26bd\ufe0f \u2b07\ufe0f\nhttps://t.co/C85xrWh0Ye https://t.co/QiIZN5Jfkn"
#         },
#         {
#             "author_id": "1439240623199068162",
#             "edit_history_tweet_ids": [
#                 "1577707220032266242"
#             ],
#             "id": "1577707220032266242",
#             "text": "Cool that #Twitter now allows gifs, videos and images in Tweets,all in one Tweet. #TwitterDev\n\n\u2b50\u2b50\u2b50\u2b50\u2b50\ud83d\ude0e\n#TwitterBuilding"
#         },
#         {
#             "author_id": "2244994945",
#             "edit_history_tweet_ids": [
#                 "1577690074862555143"
#             ],
#             "id": "1577690074862555143",
#             "text": "\ud83d\udc40 Building with the Twitter API? We want YOU to apply for the Insiders program!\n\nBenefits \u2728\n\u2705 Featured in speaking engagements\n\u2705 Attend private product feedback sessions\n\u2705 Receive increased access to Twitter data\n\u2795 More\n\nLearn more &amp; apply \ud83d\udc47\n https://t.co/ExPngx80Gb"
#         },
#         {
#             "author_id": "2244994945",
#             "edit_history_tweet_ids": [
#                 "1577644775028805632"
#             ],
#             "id": "1577644775028805632",
#             "text": "\ud83d\udc40 https://t.co/PGsPlIxVY9"
#         },
#         {
#             "author_id": "2244994945",
#             "edit_history_tweet_ids": [
#                 "1577372986176323602"
#             ],
#             "id": "1577372986176323602",
#             "text": "\ud83d\udca1 Tip Tuesday: You can let people choose who can reply to a Tweet directly from Twitter Create in v2. See how to only let followers reply to a Tweet: \u2935\ufe0f\nhttps://t.co/ZGu5ejhm2W"
#         },
#         {
#             "author_id": "2244994945",
#             "edit_history_tweet_ids": [
#                 "1577025697218023424"
#             ],
#             "id": "1577025697218023424",
#             "text": "\ud83d\udce3 If you allowlist our servers to receive activities with the Account Activity API, please note that we\u2019ve recently updated our outbound IP address ranges. \n\nLearn more here: \u2b07\ufe0f \nhttps://t.co/xM4spi519S"
#         },
#         {
#             "author_id": "2244994945",
#             "edit_history_tweet_ids": [
#                 "1576984567872749568"
#             ],
#             "id": "1576984567872749568",
#             "text": "With the Edit Tweet feature rolling out incrementally, we hope this will give you time to understand how edited Tweets are represented in the data. Learn more about edited Tweet metadata \ud83d\udc47\n\nhttps://t.co/kioijH0GeR"
#         }
#     ],
#     "meta": {
#         "newest_id": "1578414851688480769",
#         "next_token": "b26v89c19zqg8o3fpzbm7bdju99r1nfuav6nu0jozj62l",
#         "oldest_id": "1576984567872749568",
#         "result_count": 9
#     }
# }

# %%
print(bearer_token)
# Out:
# None

# %%
import requests
import os
import json

search_url = "https://api.twitter.com/2/users/1283018468707770368/liked_tweets"

# Optional params: start_time,end_time,since_id,until_id,max_results,next_token,
# expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields
query_params = None #{'query': '(from:twitterdev -is:retweet) OR #twitterdev','tweet.fields': 'author_id'}


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {BEARER_TOKEN}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


def main():
    json_response = connect_to_endpoint(search_url, query_params)
    print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
main()
# Out:
# {
#     "data": [
#         {
#             "edit_history_tweet_ids": [
#                 "1578326006032584705"
#             ],
#             "id": "1578326006032584705",
#             "text": "@Seapeekay @Dream YOOO"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1578312051931246592"
#             ],
#             "id": "1578312051931246592",
#             "text": "SAN DIEGO DAY 1 OVER\n\nwas so awesome getting to meet so many creators and fans :) love you guys https://t.co/ZuM5FYPGfa"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1578327806693416961"
#             ],
#             "id": "1578327806693416961",
#             "text": "@sylveemhm the horn sucks"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1578287053258661890"
#             ],
#             "id": "1578287053258661890",
#             "text": "@dreamwastaken Bro no one asked \ud83d\ude39\ud83d\ude39\ud83d\ude39"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1578285851850657793"
#             ],
#             "id": "1578285851850657793",
#             "text": "DREAM SMP PANEL TOMORROW"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577421545164505088"
#             ],
#             "id": "1577421545164505088",
#             "text": "oh sapnapppp https://t.co/AVHvgWaAc2"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577422500996472832"
#             ],
#             "id": "1577422500996472832",
#             "text": "@dreamwastaken 1 day there and he already became Florida man \ud83d\ude14"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577423130934808576"
#             ],
#             "id": "1577423130934808576",
#             "text": "@dreamwastaken he missed btw"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577486342753341441"
#             ],
#             "id": "1577486342753341441",
#             "text": "@dreamwastaken Crime"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577483504127877120"
#             ],
#             "id": "1577483504127877120",
#             "text": "@dreamwastaken Bro you\u2019ve never had sushi? Holy shit"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577483401921077249"
#             ],
#             "id": "1577483401921077249",
#             "text": "just had sushi for the first time, was so good yum"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577399018052849671"
#             ],
#             "id": "1577399018052849671",
#             "text": "got him a new necklace https://t.co/3Qmfc0IkxX"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577205975513067521"
#             ],
#             "id": "1577205975513067521",
#             "text": "@GeorgeNootFound I\u2019m teary eyed it was so good \ud83e\uddad"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577202416532930565"
#             ],
#             "id": "1577202416532930565",
#             "text": "i hope you all enjoyed :)"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577145677624197121"
#             ],
#             "id": "1577145677624197121",
#             "text": "call me sapnao because I have school tomorrow dude"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576923171802189824"
#             ],
#             "id": "1576923171802189824",
#             "text": "GEORGE IS CURRENTLY EDITING THE DREAM TEAM MEET UP VLOG \ud83e\udef6\ud83c\udffc"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577162255216496642"
#             ],
#             "id": "1577162255216496642",
#             "text": "Dude landed in Florida and first thing he did was drink cat water... Maybe he does belong in that state."
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577161718404640769"
#             ],
#             "id": "1577161718404640769",
#             "text": "bro actually drank patches water \ud83d\udc80"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576962903885852673"
#             ],
#             "id": "1576962903885852673",
#             "text": "oh what a @Dream"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577155187919110144"
#             ],
#             "id": "1577155187919110144",
#             "text": "@GeorgeNootFound WOOOO IM EXCITED ITS GONNA BE THE BEST"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577037865221238784"
#             ],
#             "id": "1577037865221238784",
#             "text": "I apologize for my tweet yesterday about candy corn.  They are ok.  So about that face reveal"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577046831455907841"
#             ],
#             "id": "1577046831455907841",
#             "text": "@GeorgeNotFound @DUALIPA I\u2019ll send @DUALIPA Skittles if she responds"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577155762354126848"
#             ],
#             "id": "1577155762354126848",
#             "text": "@Dream VIDEO PREMIERING IN 10 MINUTES!!! EVERYONE GO\nhttps://t.co/S3zHinnOtx"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577155000480206848"
#             ],
#             "id": "1577155000480206848",
#             "text": "WOOOOO GO WATCH \nhttps://t.co/yg8YzmF7tO"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577154939021053952"
#             ],
#             "id": "1577154939021053952",
#             "text": "I HAD PROBLEMS WITH COPYRIGHT IM SORRY VIDEO UP IN 15 MINUTES, LINK IN REPLY!!!!!"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577115620222509061"
#             ],
#             "id": "1577115620222509061",
#             "text": "@dreamwastaken That\u2019s pretty good!"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577139217120960512"
#             ],
#             "id": "1577139217120960512",
#             "text": "just need to fix this real quick then we are going WOOOO https://t.co/MCrTISo5Gk"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577117353200189441"
#             ],
#             "id": "1577117353200189441",
#             "text": "@dreamwastaken kinda epic"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577129634575323136"
#             ],
#             "id": "1577129634575323136",
#             "text": "I just met my online best friend @Dream of 7 years in real life for the first time! \n\nI\u2019ll be premiering the video on my YouTube channel GeorgeNotFound in around 30 minutes!\n\nThis is my favourite video I\u2019ve ever made and I hope you all love it as much as I do \u2764\ufe0f"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577055674659266560"
#             ],
#             "id": "1577055674659266560",
#             "text": "@GeorgeNootFound Thank you George for blessing us with the vlog in a timely fashion I look forward to watching it and may my appreciation speed you on in this endeavor"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577060308366942208"
#             ],
#             "id": "1577060308366942208",
#             "text": "OMG THIS IS ACTUALLY EPIC IM NEARLY DONE I THINK https://t.co/ijHrZutgUD"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577081302947225600"
#             ],
#             "id": "1577081302947225600",
#             "text": "@dreamwastaken Time for some mega bangers, can\u2019t wait to see what you upload :D"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577068783453474816"
#             ],
#             "id": "1577068783453474816",
#             "text": "24 million views in 21 hours.\n\ninsane. love you all \u2764\ufe0f so excited for everything coming up"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577024119161618432"
#             ],
#             "id": "1577024119161618432",
#             "text": "@GeorgeNotFound @DUALIPA wait what?!??!?!?!?"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577023854068629504"
#             ],
#             "id": "1577023854068629504",
#             "text": "HELLO @DUALIPA THIS IS IMPORTANT PLEASE REPLY TO YOUR LABEL RIGHT NOW ITS VERY IMPORTANT YOU MUST GO NOW!!!"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577009749622927360"
#             ],
#             "id": "1577009749622927360",
#             "text": "@AustinOnTwitter @pokimanelol @hasanthehun @KarlJacobs_ @TheWillNeff You better get me a good outfit"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577009800553979904"
#             ],
#             "id": "1577009800553979904",
#             "text": "@MrBeast @shonenleaks @jessix_tv Get it done for early One Piece first"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577007493716185088"
#             ],
#             "id": "1577007493716185088",
#             "text": "@shonenleaks @jessix_tv How much do I have to pay to get every episode like this?"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576728057817485312"
#             ],
#             "id": "1576728057817485312",
#             "text": "Tiktok Live is unbeatable https://t.co/b7dRf693zV"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1577002597805793280"
#             ],
#             "id": "1577002597805793280",
#             "text": "@AustinOnTwitter @pokimanelol @hasanthehun @GeorgeNotFound @TheWillNeff Free win \ud83e\udd71\ud83e\udd71"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576878345601503233"
#             ],
#             "id": "1576878345601503233",
#             "text": "If your first thought after seeing someone\u2019s face is to comment on their general attributes I think that says more about your own projections than it does about their looks."
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576957751036497923"
#             ],
#             "id": "1576957751036497923",
#             "text": "Something wicked this way comes... \ud83e\udd87\n\nGet ready for a spooktacular MCC 26 on October 22nd! \ud83c\udf83\ud83d\udc51"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576715190363635712"
#             ],
#             "id": "1576715190363635712",
#             "text": "@GeorgeNotFound cannot wait for everyone else to meet Dream \u2764\ufe0f"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576977357478723584"
#             ],
#             "id": "1576977357478723584",
#             "text": "@NarutoXposts HOW DID NO ONE TELL ME THIS WTF"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576918475754594305"
#             ],
#             "id": "1576918475754594305",
#             "text": "I AM EDITING THE DREAM TEAM MEET UP VLOG RIGHT NOW IM TRYING TO GET IT OUT TONIGHT IM GOING AS QUICK AS I CAN!!!"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1455721165553602565"
#             ],
#             "id": "1455721165553602565",
#             "text": "I LOVE U"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576693614301822979"
#             ],
#             "id": "1576693614301822979",
#             "text": "give yourself a compliment today \ud83d\ude0a"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576743782766112768"
#             ],
#             "id": "1576743782766112768",
#             "text": "not a stan in any regards but it's really gross to see the trending hashtags rn being so negative about someone's appearance."
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576779780527075328"
#             ],
#             "id": "1576779780527075328",
#             "text": "@Dream @AlecBenjamin With the power of \u2728friendship\u2728 \ud83d\ude0d https://t.co/fFBkgA8yUX"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576778974419914752"
#             ],
#             "id": "1576778974419914752",
#             "text": "@AlecBenjamin us beating the enderdragon"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576768647900827648"
#             ],
#             "id": "1576768647900827648",
#             "text": "\ud83d\ude0c @Dream https://t.co/nOt96EwU2v"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576760174056202240"
#             ],
#             "id": "1576760174056202240",
#             "text": "@Dream LETS GOOOOOOOOOO"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576768581311660038"
#             ],
#             "id": "1576768581311660038",
#             "text": "@GeorgeNotFound come to north carolina"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576749066699952129"
#             ],
#             "id": "1576749066699952129",
#             "text": "omg i just saw @dream's face"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576747662069493780"
#             ],
#             "id": "1576747662069493780",
#             "text": "@dreamwastaken Congrats dream\ud83e\udd20"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576749736102879234"
#             ],
#             "id": "1576749736102879234",
#             "text": "@Dream I wanna see a group hug!"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576747416811843584"
#             ],
#             "id": "1576747416811843584",
#             "text": "i hate seeing people get mean about people's looks... that's the only real ugly out here"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576749914989608960"
#             ],
#             "id": "1576749914989608960",
#             "text": "everyone who stayed up late going to school tomorrow https://t.co/GG9wlHlZIH"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576701570128916480"
#             ],
#             "id": "1576701570128916480",
#             "text": "@Dream Pls share with us the real time stats for that \ud83d\ude0e\ud83d\ude0e"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576742762665242624"
#             ],
#             "id": "1576742762665242624",
#             "text": "@Dream Can't wait to see you at TwitchCon, you handsome devil, you!"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576746860962025472"
#             ],
#             "id": "1576746860962025472",
#             "text": "@GeorgeNotFound Does the UK not have mosquitos?"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576747376282259456"
#             ],
#             "id": "1576747376282259456",
#             "text": "@dreamwastaken So proud of you and how far you\u2019ve come :)"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576734328926588928"
#             ],
#             "id": "1576734328926588928",
#             "text": "@dreamwastaken HISTORY. GOOD LUCK."
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576747157377335296"
#             ],
#             "id": "1576747157377335296",
#             "text": "@dreamwastaken I WILL CELEBRATE DREAM DAY EVERY YEAR UNTIL I DIE \ud83d\ude24\n\nONE HUMAN SACRIFICE ON THE DAY WILL KEEP KACEYTRON\u2019S SPIRITS AWAY"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576739423479205888"
#             ],
#             "id": "1576739423479205888",
#             "text": "ITS TIME"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576734165424164864"
#             ],
#             "id": "1576734165424164864",
#             "text": "@dreamwastaken Huge respect man :D takes a lot"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576746360128184320"
#             ],
#             "id": "1576746360128184320",
#             "text": "that was insane thanks everyone for going on this journey with me :^)"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576742342748344321"
#             ],
#             "id": "1576742342748344321",
#             "text": "@Dream So proud of you man :) it\u2019s been years in the making and you\u2019re finally on the other side of it! Excited for this new era and I\u2019m so excited to finally meet you IRL \ud83d\udc95 love u man"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576742323689771009"
#             ],
#             "id": "1576742323689771009",
#             "text": "@Dream HEY ITS YOU AND ME AND GEORGE !!"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576734633395642368"
#             ],
#             "id": "1576734633395642368",
#             "text": "@dreamwastaken It\u2019s face time \ud83d\ude0f"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576742757200146432"
#             ],
#             "id": "1576742757200146432",
#             "text": "@Dream THIS DONT FEEL REAL"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576744145237921792"
#             ],
#             "id": "1576744145237921792",
#             "text": "i already have a mosquito bite, florida sucks"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576728736862724097"
#             ],
#             "id": "1576728736862724097",
#             "text": "remember to be kind :)"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576734112207208448"
#             ],
#             "id": "1576734112207208448",
#             "text": "@dreamwastaken OH JEEZ OH MY GOD OKAY"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576741891592159233"
#             ],
#             "id": "1576741891592159233",
#             "text": "guess who https://t.co/eqSWH1wAxd"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576733981772390401"
#             ],
#             "id": "1576733981772390401",
#             "text": "@dreamwastaken AHHHHHHHHHHHHHHHHHHH"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576734329161412608"
#             ],
#             "id": "1576734329161412608",
#             "text": "@dreamwastaken OH ITS HERE ITS HERE"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576741240896651265"
#             ],
#             "id": "1576741240896651265",
#             "text": "I'M SO HAPPY FOR YOU DREAM!!! \u2764\ufe0f"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576733980983848961"
#             ],
#             "id": "1576733980983848961",
#             "text": "face reveal But it\u2019s actually me but Bald"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576739316574826497"
#             ],
#             "id": "1576739316574826497",
#             "text": "@GeorgeNootFound AHHHHHH"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576739242872827904"
#             ],
#             "id": "1576739242872827904",
#             "text": "IM EXCITED"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576732488826703874"
#             ],
#             "id": "1576732488826703874",
#             "text": "Anyone know how to put out a house fire"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576730908316815360"
#             ],
#             "id": "1576730908316815360",
#             "text": "@Dream I AM READY!!!!"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576733848737435648"
#             ],
#             "id": "1576733848737435648",
#             "text": "https://t.co/cu0S2TMxgZ"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576731796229672961"
#             ],
#             "id": "1576731796229672961",
#             "text": "@TubboLive @Dream fr \ud83e\udd28"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576731690177003521"
#             ],
#             "id": "1576731690177003521",
#             "text": "@Dream WHERE IS IT HUH!?!?!?!?!??!?! \nHUH WE ARE ALL WAITING SIR \nPLEASE"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576702181058584577"
#             ],
#             "id": "1576702181058584577",
#             "text": "@Dream Twitter is about to explode enjoy sxrolling while you can"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576702291364941824"
#             ],
#             "id": "1576702291364941824",
#             "text": "@Dream CURRENTLY ON A PLANE WITH DOGSHIT WIFI. I HAVE A 20% CHANCE I WILL BE HERE FOR THE REVEAL. THANKS PHILIPPINE AIRLINES"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576727800111058944"
#             ],
#             "id": "1576727800111058944",
#             "text": "everyone lurking on twitter right now \ud83e\uddcd\u200d\u2640\ufe0f"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576702445371080704"
#             ],
#             "id": "1576702445371080704",
#             "text": "@Dream WOOOOOOOOOOOOOOOOOOOOOOOOOOOOO"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576701752509767680"
#             ],
#             "id": "1576701752509767680",
#             "text": "@GeorgeNotFound @Dream WERE ALL CRYING BRO https://t.co/vJ87dTuNlX"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576701407155011584"
#             ],
#             "id": "1576701407155011584",
#             "text": "@Dream LETS GOOOOOOOOOOOO!!!"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576702867183874048"
#             ],
#             "id": "1576702867183874048",
#             "text": "@Dream on a real note, im proud of you boss, i cant imagine the pressure you feel rn. but also youre pretty which is unfair so whatever you'll be fine"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576695033939779584"
#             ],
#             "id": "1576695033939779584",
#             "text": "@dreamwastaken guys please how long does rendering take i need an alarm"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576708659349815296"
#             ],
#             "id": "1576708659349815296",
#             "text": "@Dream the internet is going to crash"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576697507580551168"
#             ],
#             "id": "1576697507580551168",
#             "text": "@GeorgeNotFound im here to see how many likes this gets"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576715637673426945"
#             ],
#             "id": "1576715637673426945",
#             "text": "one hour..."
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576709274830454784"
#             ],
#             "id": "1576709274830454784",
#             "text": "@Dream AHHHHH SO PROUD OF U"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576708935469322240"
#             ],
#             "id": "1576708935469322240",
#             "text": "@GeorgeNotFound ANGELS"
#         },
#         {
#             "edit_history_tweet_ids": [
#                 "1576701586683834368"
#             ],
#             "id": "1576701586683834368",
#             "text": "@Dream WHAT DO YOU MEAN 2 HOURS"
#         }
#     ],
#     "meta": {
#         "next_token": "7140dibdnow9c7btw481s8nmtjjocvaqkjll630y5ddmd",
#         "result_count": 100
#     }
# }
